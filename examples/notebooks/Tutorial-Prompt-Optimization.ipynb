# %% [markdown]
# ## Tutorial: Optimizing a Prompt
#
# ![TextGrad](https://github.com/vinid/data/blob/master/logo_full.png?raw=true)
#
# An autograd engine -- for textual gradients!
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/zou-group/TextGrad/blob/main/examples/notebooks/Prompt-Optimization.ipynb)
# [![GitHub license](https://img.shields.io/badge/License-MIT-blue.svg)](https://lbesson.mit-license.org/)
# [![Arxiv](https://img.shields.io/badge/arXiv-2406.07496-B31B1B.svg)](https://arxiv.org/abs/2406.07496)
# [![Documentation Status](https://readthedocs.org/projects/textgrad/badge/?version=latest)](https://textgrad.readthedocs.io/en/latest/?badge=latest)
# [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/textgrad)](https://pypi.org/project/textgrad/)
# [![PyPI](https://img.shields.io/pypi/v/textgrad)](https://pypi.org/project/textgrad/)
#
# **Objectives:**
#
# * In this tutorial, we will run prompt optimization.
#
# **Requirements:**
#
# * You need to have an OpenAI API key to run this tutorial. This should be set as an environment variable as OPENAI_API_KEY.

# %%
# !pip install textgrad # you might need to restart the notebook after installing textgrad
# !pip install anthropic
# !pip install litellm --upgrade
from google.colab import userdata
import os
os.environ['ANTHROPIC_API_KEY'] = userdata.get('ANTHROPIC_API_KEY')
from anthropic import Anthropic
import argparse
import concurrent
from dotenv import load_dotenv
from tqdm import tqdm
import textgrad as tg
from textgrad.tasks import load_task
import numpy as np
import random

load_dotenv(override=True)
# Out:
# Requirement already satisfied: textgrad in /usr/local/lib/python3.12/dist-packages (0.1.8)
# Requirement already satisfied: openai>=1.23.6 in /usr/local/lib/python3.12/dist-packages (from textgrad) (2.9.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from textgrad) (9.1.2)
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from textgrad) (1.2.1)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.12/dist-packages (from textgrad) (2.2.2)
# Requirement already satisfied: platformdirs>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from textgrad) (4.5.1)
# Requirement already satisfied: datasets>=2.14.6 in /usr/local/lib/python3.12/dist-packages (from textgrad) (4.0.0)
# Requirement already satisfied: diskcache>=5.6.3 in /usr/local/lib/python3.12/dist-packages (from textgrad) (5.6.3)
# Requirement already satisfied: graphviz>=0.20.3 in /usr/local/lib/python3.12/dist-packages (from textgrad) (0.21)
# Requirement already satisfied: gdown>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from textgrad) (5.2.0)
# Requirement already satisfied: litellm>=1.49.5 in /usr/local/lib/python3.12/dist-packages (from textgrad) (1.80.10)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from textgrad) (11.3.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from textgrad) (0.28.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.6->textgrad) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.6->textgrad) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.6->textgrad) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.6->textgrad) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.6->textgrad) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.6->textgrad) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.6->textgrad) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.6->textgrad) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.6->textgrad) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.6->textgrad) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.6->textgrad) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.6->textgrad) (6.0.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown>=5.2.0->textgrad) (4.13.5)
# Requirement already satisfied: aiohttp>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.49.5->textgrad) (3.13.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from litellm>=1.49.5->textgrad) (8.3.1)
# Requirement already satisfied: fastuuid>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.49.5->textgrad) (0.14.0)
# Requirement already satisfied: grpcio<1.68.0,>=1.62.3 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.49.5->textgrad) (1.67.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.49.5->textgrad) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.49.5->textgrad) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.49.5->textgrad) (4.25.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.49.5->textgrad) (2.12.3)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.49.5->textgrad) (0.12.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from litellm>=1.49.5->textgrad) (0.22.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->textgrad) (4.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx->textgrad) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->textgrad) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx->textgrad) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->textgrad) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.23.6->textgrad) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.23.6->textgrad) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.23.6->textgrad) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai>=1.23.6->textgrad) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->textgrad) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->textgrad) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->textgrad) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.49.5->textgrad) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.49.5->textgrad) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.49.5->textgrad) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.49.5->textgrad) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.49.5->textgrad) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.49.5->textgrad) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.49.5->textgrad) (1.22.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets>=2.14.6->textgrad) (1.2.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->litellm>=1.49.5->textgrad) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm>=1.49.5->textgrad) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.49.5->textgrad) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.49.5->textgrad) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.49.5->textgrad) (0.30.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm>=1.49.5->textgrad) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm>=1.49.5->textgrad) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm>=1.49.5->textgrad) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->textgrad) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.14.6->textgrad) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.14.6->textgrad) (2.5.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.7.0->litellm>=1.49.5->textgrad) (2025.11.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown>=5.2.0->textgrad) (2.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown>=5.2.0->textgrad) (1.7.1)
# Requirement already satisfied: anthropic in /usr/local/lib/python3.12/dist-packages (0.75.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Requirement already satisfied: litellm in /usr/local/lib/python3.12/dist-packages (1.80.10)
# Requirement already satisfied: aiohttp>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm) (3.13.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from litellm) (8.3.1)
# Requirement already satisfied: fastuuid>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (0.14.0)
# Requirement already satisfied: grpcio<1.68.0,>=1.62.3 in /usr/local/lib/python3.12/dist-packages (from litellm) (1.67.1)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from litellm) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (4.25.1)
# Requirement already satisfied: openai>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (2.9.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (2.12.3)
# Requirement already satisfied: python-dotenv>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (1.2.1)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (0.12.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from litellm) (0.22.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm) (1.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm) (4.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->litellm) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (0.30.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=2.8.0->litellm) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=2.8.0->litellm) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=2.8.0->litellm) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai>=2.8.0->litellm) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai>=2.8.0->litellm) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.7.0->litellm) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.7.0->litellm) (2.32.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers->litellm) (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (6.0.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm) (2.5.0)
# False

# %% [markdown]
# Let's first define some support functions

# %%
def set_seed(seed):
    np.random.seed(seed)
    random.seed(seed)

# %%
def eval_sample(item, eval_fn, model):
    """
    This function allows us to evaluate if an answer to a question in the prompt is a good answer.

    """
    x, y = item
    x = tg.Variable(x, requires_grad=False, role_description="query to the language model")
    y = tg.Variable(y, requires_grad=False, role_description="correct answer for the query")
    response = model(x)
    try:
        eval_output_variable = eval_fn(inputs=dict(prediction=response, ground_truth_answer=y))
        return int(eval_output_variable.value)
    except:
        eval_output_variable = eval_fn([x, y, response])
        eval_output_parsed = eval_fn.parse_output(eval_output_variable)
        return int(eval_output_parsed)

# %%
def eval_dataset(test_set, eval_fn, model, max_samples: int=None):
    if max_samples is None:
        max_samples = len(test_set)
    accuracy_list = []
    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
        futures = []
        for _, sample in enumerate(test_set):

            future = executor.submit(eval_sample, sample, eval_fn, model)
            futures.append(future)
            if len(futures) >= max_samples:
                break
        tqdm_loader = tqdm(concurrent.futures.as_completed(futures), total=len(futures), position=0)
        for future in tqdm_loader:
            acc_item = future.result()
            accuracy_list.append(acc_item)
            tqdm_loader.set_description(f"Accuracy: {np.mean(accuracy_list)}")
    return accuracy_list

# %%
def run_validation_revert(system_prompt: tg.Variable, results, model, eval_fn, val_set):
    val_performance = np.mean(eval_dataset(val_set, eval_fn, model))
    previous_performance = np.mean(results["validation_acc"][-1])
    print("val_performance: ", val_performance)
    print("previous_performance: ", previous_performance)
    previous_prompt = results["prompt"][-1]

    if val_performance < previous_performance:
        print(f"rejected prompt: {system_prompt.value}")
        system_prompt.set_value(previous_prompt)
        val_performance = previous_performance

    results["validation_acc"].append(val_performance)

# %%
set_seed(12)
llm_api_eval = tg.get_engine(engine_name="claude-3-opus-20240229")
llm_api_test = tg.get_engine(engine_name="claude-3-opus-20240229")
tg.set_backward_engine(llm_api_eval, override=True)

# Load the data and the evaluation function
train_set, val_set, test_set, eval_fn = load_task("BBH_object_counting", evaluation_api=llm_api_eval)
print("Train/Val/Test Set Lengths: ", len(train_set), len(val_set), len(test_set))
STARTING_SYSTEM_PROMPT = train_set.get_task_description()
# Out:
# Train/Val/Test Set Lengths:  50 100 100

# %% [markdown]
# This is the system prompt we are going to start from:

# %%
print(STARTING_SYSTEM_PROMPT)
# Out:
# You will answer a reasoning question. Think step by step. The last line of your response should be of the following format: 'Answer: $VALUE' where VALUE is a numerical value.

# %%
import numpy as np

# 定义一个清洗函数
def clean_dataset(dataset):
    cleaned = []
    for x, y in dataset:
        # 如果 x 是 numpy 类型，转成标准 int 或 str
        if isinstance(x, (np.integer, np.int64)):
            x = int(x)
        # 如果 y 是 numpy 类型，也转一下
        if isinstance(y, (np.integer, np.int64)):
            y = int(y)
        cleaned.append((x, y))
    return cleaned

# 1. 清洗你的数据集 (把 numpy.int64 变成 int)
test_set = clean_dataset(test_set)
val_set = clean_dataset(val_set)

# 2. 打印确认一下 (应该显示 <class 'int'>)
print("清洗后数据类型:", type(test_set[0][0]))
# Out:
# 清洗后数据类型: <class 'str'>

# %%
train_loader = tg.tasks.DataLoader(train_set, batch_size=3, shuffle=True)


# Testing the 0-shot performance of the evaluation engine
system_prompt = tg.Variable(STARTING_SYSTEM_PROMPT,
                            requires_grad=True,
                            role_description="system prompt to the language model")
model_evaluation = tg.BlackboxLLM(llm_api_eval, system_prompt)

system_prompt = tg.Variable(STARTING_SYSTEM_PROMPT,
                            requires_grad=True,
                            role_description="structured system prompt to a somewhat capable language model that specifies the behavior and strategies for the QA task")
model = tg.BlackboxLLM(llm_api_test, system_prompt)

optimizer = tg.TextualGradientDescent(engine=llm_api_eval, parameters=[system_prompt])

results = {"test_acc": [], "prompt": [], "validation_acc": []}
results["test_acc"].append(eval_dataset(test_set, eval_fn, model))
results["validation_acc"].append(eval_dataset(val_set, eval_fn, model))
results["prompt"].append(system_prompt.get_value())
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   1%|          | 1/100 [00:05<08:15,  5.00s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   2%|▏         | 2/100 [00:07<05:24,  3.31s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   3%|▎         | 3/100 [00:09<04:55,  3.05s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   4%|▍         | 4/100 [00:11<03:50,  2.40s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   5%|▌         | 5/100 [00:14<04:26,  2.80s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   6%|▌         | 6/100 [00:15<03:08,  2.01s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   7%|▋         | 7/100 [00:20<05:00,  3.23s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   8%|▊         | 8/100 [00:22<03:59,  2.60s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   9%|▉         | 9/100 [00:25<04:19,  2.85s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  10%|█         | 10/100 [00:30<05:09,  3.44s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  11%|█         | 11/100 [00:30<03:44,  2.52s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  12%|█▏        | 12/100 [00:36<05:05,  3.47s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  13%|█▎        | 13/100 [00:38<04:13,  2.91s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  14%|█▍        | 14/100 [00:41<04:19,  3.01s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  15%|█▌        | 15/100 [00:41<03:08,  2.22s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  16%|█▌        | 16/100 [00:46<04:19,  3.09s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  16%|█▌        | 16/100 [00:46<04:19,  3.09s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  18%|█▊        | 18/100 [00:50<03:21,  2.45s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  19%|█▉        | 19/100 [00:51<02:51,  2.12s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  20%|██        | 20/100 [00:54<03:07,  2.35s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  21%|██        | 21/100 [00:56<02:58,  2.26s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  22%|██▏       | 22/100 [00:58<02:51,  2.20s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  23%|██▎       | 23/100 [01:00<02:55,  2.28s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  24%|██▍       | 24/100 [01:05<03:50,  3.03s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  25%|██▌       | 25/100 [01:06<02:58,  2.38s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  26%|██▌       | 26/100 [01:10<03:18,  2.69s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  27%|██▋       | 27/100 [01:13<03:24,  2.80s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:
/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  75%|███████▌  | 75/100 [03:16<00:52,  2.11s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  76%|███████▌  | 76/100 [03:18<00:52,  2.19s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  77%|███████▋  | 77/100 [03:19<00:40,  1.77s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  78%|███████▊  | 78/100 [03:21<00:42,  1.95s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  79%|███████▉  | 79/100 [03:22<00:33,  1.59s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  80%|████████  | 80/100 [03:26<00:49,  2.48s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  81%|████████  | 81/100 [03:27<00:37,  1.98s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  82%|████████▏ | 82/100 [03:32<00:50,  2.78s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  83%|████████▎ | 83/100 [03:32<00:35,  2.08s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  84%|████████▍ | 84/100 [03:35<00:37,  2.32s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  85%|████████▌ | 85/100 [03:38<00:38,  2.54s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  86%|████████▌ | 86/100 [03:40<00:33,  2.36s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  87%|████████▋ | 87/100 [03:42<00:26,  2.05s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  88%|████████▊ | 88/100 [03:46<00:31,  2.67s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  88%|████████▊ | 88/100 [03:46<00:31,  2.67s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  90%|█████████ | 90/100 [03:50<00:25,  2.53s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  91%|█████████ | 91/100 [03:51<00:18,  2.01s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  92%|█████████▏| 92/100 [03:54<00:19,  2.44s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  93%|█████████▎| 93/100 [03:55<00:12,  1.82s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  94%|█████████▍| 94/100 [03:59<00:15,  2.59s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  95%|█████████▌| 95/100 [04:00<00:10,  2.01s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  96%|█████████▌| 96/100 [04:03<00:09,  2.47s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  96%|█████████▌| 96/100 [04:03<00:09,  2.47s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  98%|█████████▊| 98/100 [04:08<00:04,  2.47s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  99%|█████████▉| 99/100 [04:10<00:02,  2.25s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0: 100%|██████████| 100/100 [04:13<00:00,  2.53s/it]

# %%
for epoch in range(3):
    for steps, (batch_x, batch_y) in enumerate((pbar := tqdm(train_loader, position=0))):
        pbar.set_description(f"Training step {steps}. Epoch {epoch}")
        optimizer.zero_grad()
        losses = []
        for (x, y) in zip(batch_x, batch_y):
            if hasattr(x, 'item'): x = x.item()
            if hasattr(y, 'item'): y = y.item()

            x = str(x)
            y = str(y)
            x = tg.Variable(x, requires_grad=False, role_description="query to the language model")
            y = tg.Variable(y, requires_grad=False, role_description="correct answer for the query")
            response = model(x)
            try:
                eval_output_variable = eval_fn(inputs=dict(prediction=response, ground_truth_answer=y))
            except:
                eval_output_variable = eval_fn([x, y, response])
            losses.append(eval_output_variable)
        total_loss = tg.sum(losses)
        total_loss.backward()
        optimizer.step()

        run_validation_revert(system_prompt, results, model, eval_fn, val_set)

        print("sys prompt: ", system_prompt)
        test_acc = eval_dataset(test_set, eval_fn, model)
        results["test_acc"].append(test_acc)
        results["prompt"].append(system_prompt.get_value())
        if steps == 3:
            break
# Out:
# Training step 0. Epoch 0: : 0it [00:00, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:Idempotent backward
# INFO:textgrad:Idempotent backward
# INFO:textgrad:Idempotent backward
# INFO:textgrad:_backward_through_string_fn prompt
# INFO:textgrad:_backward_through_string_fn gradient
# INFO:textgrad:_backward_through_llm prompt
# INFO:textgrad:_backward_through_llm gradient
# INFO:textgrad:_backward_through_string_fn prompt
# INFO:textgrad:_backward_through_string_fn gradient
# INFO:textgrad:_backward_through_llm prompt
# INFO:textgrad:_backward_through_llm gradient
# INFO:textgrad:_backward_through_string_fn prompt
# INFO:textgrad:_backward_through_string_fn gradient
# INFO:textgrad:_backward_through_llm prompt
# INFO:textgrad:_backward_through_llm gradient
# INFO:textgrad:TextualGradientDescent prompt for update
# INFO:textgrad:TextualGradientDescent optimizer response
# INFO:textgrad:TextualGradientDescent updated text
#   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  30%|███       | 30/100 [00:00<00:00, 288.12it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  64%|██████▍   | 64/100 [00:00<00:00, 314.33it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0: 100%|██████████| 100/100 [00:00<00:00, 323.25it/s]
# val_performance:  1.0
# previous_performance:  1.0
# sys prompt:  You will answer a reasoning question. Think step by step. The last line of your response should be of the following format: 'Answer: $VALUE' where VALUE is a numerical value.
#   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9761904761904762:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9767441860465116:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9772727272727273:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 0.9777777777777777:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9782608695652174:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9787234042553191:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 0.9791666666666666:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9795918367346939:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 0.98:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]              INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9803921568627451:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9807692307692307:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9811320754716981:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9814814814814815:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9818181818181818:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9821428571428571:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9824561403508771:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 0.9827586206896551:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9830508474576272:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9833333333333333:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 0.9836065573770492:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9841269841269841:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.984375:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]          INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9846153846153847:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 0.9848484848484849:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9850746268656716:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 0.9852941176470589:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9714285714285714:  35%|███▌      | 35/100 [00:00<00:00, 349.25it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9714285714285714:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.971830985915493:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s] INFO:textgrad:LLMCall function forward
# Accuracy: 0.9722222222222222:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9726027397260274:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9733333333333334:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9736842105263158:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9743589743589743:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9746835443037974:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.975:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]             INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9753086419753086:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.975609756097561:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s] INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9759036144578314:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9761904761904762:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 0.9764705882352941:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9767441860465116:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9770114942528736:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9772727272727273:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 0.9775280898876404:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9777777777777777:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.978021978021978:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s] INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9782608695652174:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.978494623655914:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s] INFO:textgrad:StringBasedFunction
# Accuracy: 0.9787234042553191:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9789473684210527:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 0.9791666666666666:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.979381443298969:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s] INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9795918367346939:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9797979797979798:  70%|███████   | 70/100 [00:00<00:00, 348.64it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 0.98: 100%|██████████| 100/100 [00:00<00:00, 293.69it/s]
# Training step 1. Epoch 0: : 1it [01:08, 68.99s/it]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:Idempotent backward
# INFO:textgrad:Idempotent backward
# INFO:textgrad:Idempotent backward
# INFO:textgrad:_backward_through_string_fn prompt
# INFO:textgrad:_backward_through_string_fn gradient
# INFO:textgrad:_backward_through_llm prompt
# INFO:textgrad:_backward_through_llm gradient
# INFO:textgrad:_backward_through_string_fn prompt
# INFO:textgrad:_backward_through_string_fn gradient
# INFO:textgrad:_backward_through_llm prompt
# INFO:textgrad:_backward_through_llm gradient
# INFO:textgrad:_backward_through_string_fn prompt
# INFO:textgrad:_backward_through_string_fn gradient
# INFO:textgrad:_backward_through_llm prompt
# INFO:textgrad:_backward_through_llm gradient
# INFO:textgrad:TextualGradientDescent prompt for update
# INFO:textgrad:TextualGradientDescent optimizer response
# INFO:textgrad:TextualGradientDescent updated text
# INFO:textgrad:LLMCall function forward
#   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  33%|███▎      | 33/100 [00:00<00:00, 324.89it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  66%|██████▌   | 66/100 [00:00<00:00, 246.33it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  92%|█████████▏| 92/100 [00:00<00:00, 221.07it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  92%|█████████▏| 92/100 [00:00<00:00, 221.07it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  92%|█████████▏| 92/100 [00:00<00:00, 221.07it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  92%|█████████▏| 92/100 [00:00<00:00, 221.07it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  92%|█████████▏| 92/100 [00:00<00:00, 221.07it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  92%|█████████▏| 92/100 [00:00<00:00, 221.07it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0: 100%|██████████| 100/100 [00:00<00:00, 231.46it/s]
# INFO:textgrad:LLMCall function forward
# val_performance:  1.0
# previous_performance:  1.0
# sys prompt:  You will answer a reasoning question. Think step by step. The last line of your response should be of the following format: 'Answer: $VALUE' where VALUE is a numerical value.
# INFO:textgrad:StringBasedFunction
#   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  21%|██        | 21/100 [00:00<00:00, 205.17it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# ...
# Accuracy: 1.0:  76%|███████▌  | 76/100 [00:00<00:00, 365.82it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  76%|███████▌  | 76/100 [00:00<00:00, 365.82it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  76%|███████▌  | 76/100 [00:00<00:00, 365.82it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  76%|███████▌  | 76/100 [00:00<00:00, 365.82it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  76%|███████▌  | 76/100 [00:00<00:00, 365.82it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  76%|███████▌  | 76/100 [00:00<00:00, 365.82it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  76%|███████▌  | 76/100 [00:00<00:00, 365.82it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  76%|███████▌  | 76/100 [00:00<00:00, 365.82it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0: 100%|██████████| 100/100 [00:00<00:00, 326.24it/s]
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# val_performance:  1.0
# previous_performance:  1.0
# sys prompt:  You will answer a reasoning question. Think step by step. The last line of your response should be of the following format: 'Answer: $VALUE' where VALUE is a numerical value.
# INFO:textgrad:StringBasedFunction
#   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:   0%|          | 0/100 [00:00<?, ?it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 1.0:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9761904761904762:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9767441860465116:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 0.9772727272727273:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9777777777777777:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9782608695652174:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 0.9787234042553191:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9791666666666666:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9795918367346939:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.98:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]              INFO:textgrad:StringBasedFunction
# Accuracy: 0.9803921568627451:  23%|██▎       | 23/100 [00:00<00:00, 227.92it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 0.9803921568627451:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9807692307692307:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 0.9811320754716981:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9818181818181818:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9821428571428571:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9824561403508771:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9827586206896551:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9830508474576272:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9833333333333333:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9836065573770492:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9838709677419355:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9841269841269841:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.984375:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]          INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9846153846153847:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9848484848484849:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9850746268656716:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 0.9852941176470589:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9855072463768116:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9714285714285714:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 0.971830985915493:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s] INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9722222222222222:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9726027397260274:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.972972972972973:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s] INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9733333333333334:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.974025974025974:  51%|█████     | 51/100 [00:00<00:00, 256.81it/s] INFO:textgrad:LLMCall function forward
# Accuracy: 0.974025974025974:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9743589743589743:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9746835443037974:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.975:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]             INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9753086419753086:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.975609756097561:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s] INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9759036144578314:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9761904761904762:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9764705882352941:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 0.9767441860465116:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9770114942528736:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9772727272727273:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9775280898876404:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9777777777777777:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 0.978021978021978:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s] INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9782608695652174:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 0.978494623655914:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s] INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9787234042553191:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:StringBasedFunction
# Accuracy: 0.9789473684210527:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:LLMCall function forward
# Accuracy: 0.9791666666666666:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.979381443298969:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s] INFO:textgrad:LLMCall function forward
# INFO:textgrad:StringBasedFunction
# INFO:textgrad:LLMCall function forward
# Accuracy: 0.9795918367346939:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 0.9797979797979798:  77%|███████▋  | 77/100 [00:00<00:00, 234.25it/s]INFO:textgrad:StringBasedFunction
# Accuracy: 0.98: 100%|██████████| 100/100 [00:00<00:00, 241.35it/s]
# Training step 3. Epoch 2: : 3it [07:03, 141.14s/it]
